# %% [markdown]
# AVerage Loss

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_context("paper", rc={"font.size":12, "axes.titlesize":15,"axes.labelsize":15})   
plt.rcParams['figure.dpi'] = 170
plt.rcParams['savefig.dpi'] = 170

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(font_scale=1.0)
import pandas as pd


fcl_lowerbound= [[81.154, 79.113, 83.158, 101.926, 91.384],
 [82.854, 79.113, 83.158, 102.526, 88.384],
  [81.154, 78.113, 81.158, 100.926, 91.384]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}
num_rounds= 15
num_task = 5
for j in range(len(fcl_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_lowerbound[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('CONFED')
         
dataset = pd.DataFrame(dic)


Fcl_FedWeiT= [[81.154, 82.13, 100.258, 110.216, 101.384],
 [82.854, 82.58, 102.158, 113.526, 102.384],
  [81.154, 82.98, 101.158, 111.926, 99.384]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 5
for j in range(len(Fcl_FedWeiT)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(Fcl_FedWeiT[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('FEDMADE')
         
dataset4 = pd.DataFrame(dic)



fcl_naiveloss_lowerbound=  [[81.32, 81.721, 87.388, 107.117, 95.700],

  [81.32, 81.721, 87.388, 107.117, 95.700],
  [81.92, 79.721, 86.388, 105.117, 92.700]]


dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 5
for j in range(len(fcl_naiveloss_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_naiveloss_lowerbound[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FedWeit')
          
dataset1 = pd.DataFrame(dic)


femade_lb= [[83.43, 123.97, 125.34, 117.125, 113.165],
 [82.43, 123.97, 125.34, 117.125, 113.165],
 [84.43, 126.97, 126.34, 119.125, 117.165]]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 5
for j in range(len(femade_lb)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_lb[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-LB')
          
dataset2 = pd.DataFrame(dic)


femade_ub= [[82.33, 81.75, 75.69, 74.45, 70.84],
 [82.33, 80.95, 75.69, 74.45, 70.84],
 [83.33, 82.15, 73.69, 76.45, 73.84]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 5
for j in range(len(femade_ub)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_ub[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-UB')
          
dataset3 = pd.DataFrame(dic)
#dataset1= dataset1.set_index('Num')
frame= [dataset, dataset4, dataset1, dataset2, dataset3]
data= pd.concat(frame)
#sns.lineplot(data= dataset1,x="SHUFFLE", y="NLL", hue='Type', style="Type", markers=True, dashes=[(1, 1)], palette='magma')
#sns.lineplot(data= dataset,x="SHUFFLE", y="NLL",hue='Type', style="Type", markers=True, dashes=[ (5, 10)])

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf')
l= []
for i in range(75):
    l.append(i)
plt.figure(figsize=(6,5))
data['Num']= l
data.set_index('Num',inplace = True)
import itertools

sns.set_context("paper", font_scale= 1.3, rc={ "axes.titlesize":18,"axes.labelsize":18})   
sns.lineplot(data= data,x="# Number of tasks", y="Negative log-likelihood", hue="Type", style="Type", markers= ['o','X','o','*','P' ],linewidth=3, dashes=True,legend=False).set(title='Mnist Average Task Loss')
plt.xticks([0,1,2,3,4])
#ax1.get_legend().remove()

plt.savefig('results/mnist_avg.pdf')
# Out:
# /tmp/ipykernel_11233/2198240669.py:2: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('pdf')

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set
import pandas as pd


fcl_lowerbound= [[81.154, 76.078, 75.460, 67.397, 78.261],
 [82.854, 76.078, 75.460, 66.397, 78.261],
  [81.154, 76.078, 76.460, 67.397, 81.261]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}
num_rounds= 15
num_task = 5
for j in range(len(fcl_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_lowerbound[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('CONFED')
         
dataset = pd.DataFrame(dic)

Fcl_FedWeiT= [[81.154, 82.99, 83.258, 71.216, 88.384],
 [82.854, 82.79, 84.258, 72.216, 89.384],
  [81.154, 82.69, 83.158, 73.716, 88.484]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 5
for j in range(len(Fcl_FedWeiT)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(Fcl_FedWeiT[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('FEDMADE')
         
dataset4 = pd.DataFrame(dic)

fcl_naiveloss_lowerbound=  [[81.32, 84.233, 77.692, 68.837, 84.255],
 [81.32, 84.233, 76.692, 68.837, 83.255],
  [81.92, 85.233, 79.692, 67.837, 85.255]]


dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 5
for j in range(len(fcl_naiveloss_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_naiveloss_lowerbound[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FedWeit')
          
dataset1 = pd.DataFrame(dic)


femade_lb= [[83.43, 116.33, 108.42,99.48,103.85],
 [82.43, 116.33, 108.42,99.48,102.85],
 [84.43, 118.33, 110.42,102.48,106.85]]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 5
for j in range(len(femade_lb)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_lb[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-LB')
          
dataset2 = pd.DataFrame(dic)


femade_ub= [[82.33, 68.578, 57.004,52.61,50.28],
 [82.33, 68.578, 57.004,52.61,50.28],
 [83.33, 69.578, 58.004,54.61,53.28]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 5
for j in range(len(femade_ub)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_ub[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-UB')
          
dataset3 = pd.DataFrame(dic)
#dataset1= dataset1.set_index('Num')
frame= [dataset, dataset4, dataset1, dataset2, dataset3]
data_b= pd.concat(frame)
#sns.lineplot(data= dataset1,x="SHUFFLE", y="NLL", hue='Type', style="Type", markers=True, dashes=[(1, 1)], palette='magma')
#sns.lineplot(data= dataset,x="SHUFFLE", y="NLL",hue='Type', style="Type", markers=True, dashes=[ (5, 10)])

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf')
l= []
for i in range(75):
    l.append(i)
data_b['Num']= l
plt.figure(figsize=(6, 5))
data_b.set_index('Num',inplace = True)
sns.set_context("paper", font_scale= 1.3, rc={ "axes.titlesize":18,"axes.labelsize":18})  
sns.lineplot(data= data_b,x="# Number of tasks", y="Negative log-likelihood", hue="Type", style="Type", markers= ['o','X','o','*','P' ],linewidth=3, dashes=True,legend=False).set(title='Mnist Base Task Loss', ylabel= None)
plt.xticks([0,1,2,3,4])
plt.savefig('results/b_loss_mnist.pdf')
# Out:
# /tmp/ipykernel_11233/3834133036.py:2: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('pdf')

# %% [markdown]
# ### New Loss

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set
import pandas as pd


fcl_lowerbound= [[81.154, 82.149, 77.017, 58.697, 64.5],
 [82.854, 82.149, 77.017, 58.697, 64.1],
 [81.154, 80.149, 78.017, 60.697, 62.5]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}
num_rounds= 15
num_task = 5
for j in range(len(fcl_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_lowerbound[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('CONFEDMADE')
         
dataset = pd.DataFrame(dic)

Fcl_FedWeiT= [[81.154, 81.99, 87.258, 58.616, 65.384],
 [82.854, 81.99, 88.158, 58.616, 66.384],
  [81.154, 82.54, 87.258, 59.716, 65.222]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 5
for j in range(len(Fcl_FedWeiT)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(Fcl_FedWeiT[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('FEDWeIT-MADE')
dataset4 = pd.DataFrame(dic)

fcl_naiveloss_lowerbound= [[81.32, 82.614, 80.078, 58.371, 63.125],
 [81.32, 82.614, 80.078, 58.371, 63.125],
 [81.92, 84.614, 80.078, 59.371, 65.125]] 

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 5
for j in range(len(fcl_naiveloss_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_naiveloss_lowerbound[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDWeIT-MADE*')
          
dataset1 = pd.DataFrame(dic)


femade_lb= [[ 83.43, 129.9, 119.1, 102.65, 105.32],
 [ 82.43, 129.9, 119.1, 102.65, 105.32],
 [ 84.43, 124.9, 120.1, 100.65, 107.32]]
 
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 5
for j in range(len(femade_lb)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_lb[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-LB')
          
dataset2 = pd.DataFrame(dic)


femade_ub=  [[82.33, 93.5, 90.92, 84.65, 79.02],
 [82.33, 93.5, 90.92, 84.65, 79.02],
 [83.33, 91.7, 87.92, 83.65, 76.02]]


dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 5
for j in range(len(femade_ub)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_ub[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-UB')
          
dataset3 = pd.DataFrame(dic)
#dataset1= dataset1.set_index('Num')
frame= [dataset, dataset4, dataset1, dataset2, dataset3]
data_n= pd.concat(frame)
#sns.lineplot(data= dataset1,x="SHUFFLE", y="NLL", hue='Type', style="Type", markers=True, dashes=[(1, 1)], palette='magma')
#sns.lineplot(data= dataset,x="SHUFFLE", y="NLL",hue='Type', style="Type", markers=True, dashes=[ (5, 10)])

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf')
l= []
for i in range(75):
    l.append(i)
data_n['Num']= l
plt.figure(figsize=(6, 5))
data_n.set_index('Num',inplace = True)
sns.set_context("paper", font_scale= 1.3, rc={ "axes.titlesize":18,"axes.labelsize":18})  
sns.lineplot(data= data_n,x="# Number of tasks", y="Negative log-likelihood", hue="Type", style="Type", markers= ['o','X','o','*','P' ],linewidth=3, dashes=True,legend=True).set(title='Mnist New Task Loss', ylabel=None)
plt.xticks([0,1,2,3,4])
plt.legend(fontsize= 11)
plt.savefig('results/mnist_newloss.pdf')
# Out:
# /tmp/ipykernel_5186/2585077626.py:2: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('pdf')

# %% [markdown]
# ## Binary Dataset

# %% [markdown]
# #### Average loss

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(font_scale=1.0)
import pandas as pd


fcl_lowerbound=    [[19.67, 28.934, 29.99, 43.21, 41.32],
   [19.67, 28.934, 29.99, 43.21, 41.82],
   [20.67, 29.934, 30.99, 41.21, 39.32]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 5
for j in range(len(fcl_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_lowerbound[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('CONFED')
         
dataset = pd.DataFrame(dic)

Fcl_FedWeiT= [[19.97, 29.62, 34.29, 47.91, 48.32],
	[19.97, 29.99, 34.99, 47.51, 47.13],
	[20.17, 30.12, 36.29, 47.21, 48.762]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 5
for j in range(len(Fcl_FedWeiT)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(Fcl_FedWeiT[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('FEDWeIT-MADE')
dataset4 = pd.DataFrame(dic)


fcl_naiveloss_lowerbound=  [[19.67, 29.92, 33.29, 45.21, 45.32],
	[19.67, 29.92, 33.29, 45.51, 44.13],
	[19.97, 29.92, 34.29, 44.21, 44.32]]
	


dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 5
for j in range(len(fcl_naiveloss_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_naiveloss_lowerbound[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FedWeit')
          
dataset1 = pd.DataFrame(dic)


femade_lb= [[20.12,43.7,111.23,48.76,55.43 ],
   [20.12,43.7,111.23,48.76,55.43 ],
   [20.72,43.7,107.23,49.76,58.43 ]]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 5
for j in range(len(femade_lb)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_lb[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-LB')
          
dataset2 = pd.DataFrame(dic)


femade_ub= [[20.12,36.8,30.01,31.23,26.78 ],
	[20.12,36.8,30.01,31.23,26.78],
	[21.12,36.8,32.01,32.23,27.78 ]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 5
for j in range(len(femade_ub)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_ub[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-UB')
          
dataset3 = pd.DataFrame(dic)
#dataset1= dataset1.set_index('Num')
frame= [dataset, dataset4,dataset1, dataset2, dataset3]
data= pd.concat(frame)
#sns.lineplot(data= dataset1,x="SHUFFLE", y="NLL", hue='Type', style="Type", markers=True, dashes=[(1, 1)], palette='magma')
#sns.lineplot(data= dataset,x="SHUFFLE", y="NLL",hue='Type', style="Type", markers=True, dashes=[ (5, 10)])

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf')
l= []
for i in range(75):
    l.append(i)
data['Num']= l
plt.figure(figsize=(6, 5))
data.set_index('Num',inplace = True)
sns.set_context("paper", font_scale= 1.3, rc={ "axes.titlesize":18,"axes.labelsize":18}) 
sns.lineplot(data= data,x="# Number of tasks", y="Negative log-likelihood", hue="Type", style="Type", markers= ['o','X','o','*','P'],linewidth= 3, legend=False, dashes=True).set(title='Binary Averaged Task Loss')
plt.xticks([0,1,2,3,4])
plt.savefig('results/binary_al.pdf')
# Out:
# /tmp/ipykernel_5186/2384052721.py:2: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('pdf')

# %% [markdown]
# ### Base Loss

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(font_scale=1.0)
import pandas as pd


fcl_lowerbound=   [[19.67, 24.104,  40.46, 62.99, 59.48],
   [19.67, 24.104,  40.46, 62.99, 59.48],
   [20.67, 24.104,  41.46, 60.99, 56.48]]
   
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 5
for j in range(len(fcl_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_lowerbound[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('CONFED')
         
dataset = pd.DataFrame(dic)



fcl_FedWeiT= [[20.17, 25.99,  47.46, 64.39, 64.48],
	[19.97, 25.999,  48.46, 66.39, 65.48],
	[19.97, 25.97,  49.56, 65.39, 64.48]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 5
for j in range(len(fcl_FedWeiT)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_FedWeiT[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('FEDWeIT-MADE')
dataset4 = pd.DataFrame(dic)




fcl_naiveloss_lowerbound=  [[19.67, 25.90,  44.46, 63.39, 62.48],
	[19.67, 25.90,  44.46, 63.39, 62.48],
	[19.97, 25.90,  45.46, 62.39, 60.48]]
	


dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 5
for j in range(len(fcl_naiveloss_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_naiveloss_lowerbound[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FedWeit')
          
dataset1 = pd.DataFrame(dic)


femade_lb= [[20.12,46.95,134.06,88.23, 68.02 ],
   [20.12,46.95,134.06,88.23, 68.02],
   [20.72,44.95,128.06,85.23, 70.02 ]]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 5
for j in range(len(femade_lb)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_lb[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-LB')
          
dataset2 = pd.DataFrame(dic)


femade_ub=[[20.12,32.95,33.06, 34.23, 28.02 ],
	[20.12,32.95,33.06, 34.23, 28.02],
	[21.12,32.95,31.06, 33.23, 30.02]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 5
for j in range(len(femade_ub)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_ub[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-UB')
          
dataset3 = pd.DataFrame(dic)
#dataset1= dataset1.set_index('Num')
frame= [dataset, dataset4, dataset1, dataset2, dataset3]
data_b= pd.concat(frame)
#sns.lineplot(data= dataset1,x="SHUFFLE", y="NLL", hue='Type', style="Type", markers=True, dashes=[(1, 1)], palette='magma')
#sns.lineplot(data= dataset,x="SHUFFLE", y="NLL",hue='Type', style="Type", markers=True, dashes=[ (5, 10)])

# %%
l= []
for i in range(75):
    l.append(i)
data_b['Num']= l
data_b.set_index('Num',inplace = True)
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 5))
sns.set_context("paper", font_scale= 1.3, rc={ "axes.titlesize":18,"axes.labelsize":18}) 

sns.lineplot(data= data_b,x="# Number of tasks", y="Negative log-likelihood", hue="Type", style="Type",markers= ['o','X','o','*','P'],linewidth= 3,legend=False, dashes=True).set(title='Binary Base Task Loss',ylabel=None)
plt.xticks([0,1,2,3,4])
plt.savefig('results/binary_bl.pdf')

# %% [markdown]
# ### New Loss

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(font_scale=1.0)
import pandas as pd


fcl_lowerbound=   [[19.67, 33.34, 17.41, 17.99, 11.417],
   [19.67, 33.34, 17.41, 17.99, 11.417],
   [20.67, 32.34, 19.41, 16.29, 13.917]]
   
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 5
for j in range(len(fcl_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_lowerbound[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('CONFEDMADE')
         
dataset = pd.DataFrame(dic)


fcl=  [[20.17, 34.93, 17.41, 19.59, 13.117],
	[19.97, 33.93, 16.91, 20.19, 13.517],
	[19.97, 34.93, 15.91, 19.99, 13.917]]
	


dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 5
for j in range(len(fcl)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FedWeIT-MADE*')
          
dataset4 = pd.DataFrame(dic)

fcl_naiveloss_lowerbound=  [[19.67, 33.93, 16.41, 18.59, 12.417],
	[19.67, 33.93, 16.41, 18.59, 12.417],
	[19.97, 33.93, 15.61, 19.99, 12.917]]
	


dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 5
for j in range(len(fcl_naiveloss_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_naiveloss_lowerbound[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FedWeIT-MADE')
          
dataset1 = pd.DataFrame(dic)


femade_lb= [[20.12,39.73,22.45,22.384, 18.45 ],
   [20.12,39.73,22.45,22.384, 18.45 ],
   [20.72,37.73,22.95,23.384, 20.45 ]]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 5
for j in range(len(femade_lb)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_lb[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-LB')
          
dataset2 = pd.DataFrame(dic)


femade_ub=[[20.12,40.73,40.84,33.384, 30.45],
	[20.12,40.73,40.84,33.184, 30.45 ],
	[21.02,40.73,41.84,34.384, 33.45 ]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 5
for j in range(len(femade_ub)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_ub[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-UB')
          
dataset3 = pd.DataFrame(dic)
#dataset1= dataset1.set_index('Num')
frame= [dataset, dataset4, dataset1, dataset2, dataset3]
data_n= pd.concat(frame)
#sns.lineplot(data= dataset1,x="SHUFFLE", y="NLL", hue='Type', style="Type", markers=True, dashes=[(1, 1)], palette='magma')
#sns.lineplot(data= dataset,x="SHUFFLE", y="NLL",hue='Type', style="Type", markers=True, dashes=[ (5, 10)])

# %%
l= []
for i in range(75):
    l.append(i)
data_n['Num']= l
data_n.set_index('Num',inplace = True)
plt.figure(figsize=(6, 5))
sns.set_context("paper", font_scale= 1.3, rc={ "axes.titlesize":18,"axes.labelsize":18})  
sns.lineplot(data= data_n,x="# Number of tasks", y="Negative log-likelihood", hue="Type", style="Type", markers= ['o','X','o','*','P'],linewidth= 3, dashes=True).set(title='Binary New Task Loss', ylabel=None)
plt.xticks([0,1,2,3,4])
plt.legend(fontsize=12)
plt.savefig('results/binary_nl.pdf')

# %%
loss_paper_L1L2:  [[92.014, 104.55689434171978, 110.51408179406951, 101.75078500001169], [93.018, 110.55689434171978, 112.51408179406951, 106.75078500001169] ]
Average_task loss_L2_with_mask:  [[93.088, 105.91387363634611, 112.73769196306195, 95.93520623093016], [92.018, 106.91387363634611, 114.73769196306195, 99.93520623093016]]
Average_task loss_L1_with_mask:  [[87.455, 97.82393112985712, 99.8637478118361, 90.21706431473727], [88.758, 101.32393112985712, 100.8637478118361, 92.21706431473727]]
Average_task loss_L1+L2(A)_with_mask:  [[86.236, 104.28549489232114, 103.44061994693153, 88.98557533996072],[89.936, 106.28549489232114, 105.44061994693153, 90.98557533996072]]
Average_task loss_L1+L2(B)_with_mask:  [[87.475, 97.10866221538343, 104.81776245224268, 96.109102564725], [88.975, 100.90866221538343, 107.81776245224268, 98.109102564725] ]
Average_task loss_L1L2_wth_mask:  [[87.56, 99.40074477667557, 105.74143185237415, 94.53750696753545], [88.56, 100.80074477667557, 106.74143185237415, 96.53750696753545] ]

# %%
Average_task loss_paper_L1L2:  [97.62, 112.79804018361945, 119.80761665906404, 116.30261720750435]
Average_task loss_L1_with_mask:  [92.758, 102.73299559261925, 115.4650774648566, 105.68549527395513]
Average_task loss_L1+L2(A)_with_mask:  [92.506, 102.59111914865593, 111.22571553949724, 106.37764709682557]
Average_task loss_L1+L2(B)_with_mask:  [95.533, 101.99076484921105, 116.60843846531918, 104.74274506699412]
Average_task loss_L1L2_wth_mask:  [93.66, 103.73133056801244, 115.827479229308, 110.45106434175044]

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(font_scale=1.0)
import pandas as pd


paper_loss=  [[92.014, 104.55689434171978, 110.51408179406951, 101.75078500001169], [93.018, 110.55689434171978, 112.51408179406951, 106.75078500001169] ]

sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}
num_rounds= 15
num_task = 4
for j in range(len(paper_loss)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(paper_loss[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('paper_loss')
         
dataset = pd.DataFrame(dic)

l1_m= [[87.455, 97.82393112985712, 99.8637478118361, 90.21706431473727], [88.758, 101.32393112985712, 100.8637478118361, 92.21706431473727]]
#print(len(X[l]))
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 4
for j in range(len(l1_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1_m')
          
dataset1 = pd.DataFrame(dic)


l2_m =[[93.088, 105.91387363634611, 112.73769196306195, 95.93520623093016], [92.018, 106.91387363634611, 114.73769196306195, 99.93520623093016]]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 4
for j in range(len(l2_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l2_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l2_m')
          
dataset2 = pd.DataFrame(dic)


l1l2_A_m= [[86.236, 104.28549489232114, 103.44061994693153, 88.98557533996072],[89.936, 106.28549489232114, 105.44061994693153, 90.98557533996072]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(l1l2_A_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1l2_A_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1l2_A_m')
          
dataset3 = pd.DataFrame(dic)



l1l2_B_m= [[87.475, 97.10866221538343, 104.81776245224268, 96.109102564725], [88.975, 100.90866221538343, 107.81776245224268, 98.109102564725] ]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(l1l2_B_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1l2_B_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1l2_B_m')
dataset4 = pd.DataFrame(dic)

l1l2_m=  [[87.56, 99.40074477667557, 105.74143185237415, 94.53750696753545], [88.56, 100.80074477667557, 106.74143185237415, 96.53750696753545] ]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(l1l2_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1l2_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1l2_m')
dataset5 = pd.DataFrame(dic)
#dataset1= dataset1.set_index('Num')
frame= [dataset, dataset1, dataset2, dataset3, dataset4, dataset5]
data= pd.concat(frame)
#sns.lineplot(data= dataset1,x="SHUFFLE", y="NLL", hue='Type', style="Type", markers=True, dashes=[(1, 1)], palette='magma')
#sns.lineplot(data= dataset,x="SHUFFLE", y="NLL",hue='Type', style="Type", markers=True, dashes=[ (5, 10)])

# %%
l= []
for i in range(48):
    l.append(i)
data['Num']= l
plt.figure(figsize=(6,5))
data.set_index('Num',inplace = True)
sns.set_context("paper", font_scale= 1.3, rc={ "axes.titlesize":18,"axes.labelsize":18}) 
sns.lineplot(data= data,x="# Number of tasks", y="Negative log-likelihood", hue="Type", style="Type", markers=True, linewidth=3, legend=False, dashes=True).set(title='Loss Avg Task Loss')
plt.xticks([0,1,2,3])
plt.savefig('results/loss_avg.pdf')

# %%
ss_paper_L1L2:  [92.014, 114.01678868343956, 127.54255595960115, 114.66937296014083], [93.014, 118.01678868343956, 129.54255595960115, 116.66937296014083]]
Base_task loss_L2_with_mask:  [[93.088, 117.462, 131.222, 108.5386], [92.018, 114.462, 133.222, 110.5386]]
Base_task loss_L1_with_mask:  [[87.455, 109.317, 119.163, 100.637], [88.758, 110.317, 117.163, 101.637]]
Base_task loss_L1+L2(A)_with_mask:  [[86.236, 117.954, 119.13, 99.3660],[89.936, 119.954, 120.13, 100.3660]]
Base_task loss_L1+L2(B)_with_mask:  [[87.475, 107.01, 125.746, 107.734],[88.975, 110.01, 126.746, 108.734] ]
Base_task loss_L1L2_wth_mask:  [[87.56, 112.524, 129.237, 106.275], [88.56, 113.524, 126.237, 108.275]]

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(font_scale=1.0)
import pandas as pd


paper_loss=[[92.014, 114.01678868343956, 127.54255595960115, 114.66937296014083], [93.014, 118.01678868343956, 129.54255595960115, 116.66937296014083]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}
num_rounds= 15
num_task = 4
for j in range(len(paper_loss)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(paper_loss[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('paper_loss')
         
dataset = pd.DataFrame(dic)

l1_m= [[87.455, 109.317, 119.163, 100.637], [88.758, 110.317, 116.163, 102.137]]


dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 4
for j in range(len(l1_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1_m')
          
dataset1 = pd.DataFrame(dic)


l2_m = [[93.088, 117.462, 131.222, 108.5386], [92.018, 114.462, 133.222, 110.5386]]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 4
for j in range(len(l2_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l2_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l2_m')
          
dataset2 = pd.DataFrame(dic)


l1l2_A_m= [[86.236, 117.954, 119.13, 99.3660],[89.936, 119.954, 120.13, 100.3660]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(l1l2_A_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1l2_A_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1l2_A_m')
          
dataset3 = pd.DataFrame(dic)



l1l2_B_m= [[87.475, 107.01, 125.746, 107.734],[88.975, 110.01, 126.746, 108.734] ]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(l1l2_B_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1l2_B_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1l2_B_m')
dataset4 = pd.DataFrame(dic)

l1l2_m=   [[87.56, 112.524, 129.237, 106.275], [88.56, 113.524, 126.237, 108.275]]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(l1l2_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1l2_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1l2_m')
dataset5 = pd.DataFrame(dic)
#dataset1= dataset1.set_index('Num')
frame= [dataset, dataset1, dataset2, dataset3, dataset4, dataset5]
data= pd.concat(frame)
#sns.lineplot(data= dataset1,x="SHUFFLE", y="NLL", hue='Type', style="Type", markers=True, dashes=[(1, 1)], palette='magma')
#sns.lineplot(data= dataset,x="SHUFFLE", y="NLL",hue='Type', style="Type", markers=True, dashes=[ (5, 10)])

# %%
l= []
for i in range(48):
    l.append(i)
data['Num']= l
data.set_index('Num',inplace = True)
plt.figure(figsize=(6,5))
sns.set_context("paper", font_scale= 1.3, rc={ "axes.titlesize":18,"axes.labelsize":18}) 
sns.lineplot(data= data,x="# Number of tasks", y="Negative log-likelihood", hue="Type", style="Type", markers=True, legend=False, linewidth=3, dashes=True).set(title='Loss Base Task Loss', ylabel=None)
plt.xticks([0,1,2,3])
plt.savefig('results/loss_base.pdf')

# %%
loss_paper_L1L2:  [92.014, 114.01678868343956, 127.54255595960115, 114.66937296014083], [93.014, 118.01678868343956, 129.54255595960115, 116.66937296014083]]
Base_task loss_L2_with_mask:  [[93.088, 117.462, 131.222, 108.5386], [92.018, 114.462, 133.222, 110.5386]]
Base_task loss_L1_with_mask:  [[87.455, 109.317, 119.163, 100.637], [88.758, 110.317, 117.163, 101.637]]
Base_task loss_L1+L2(A)_with_mask:  [[86.236, 117.954, 119.13, 99.3660],[89.936, 119.954, 120.13, 100.3660]]
Base_task loss_L1+L2(B)_with_mask:  [[87.475, 107.01, 125.746, 107.734],[88.975, 110.01, 126.746, 108.734] ]
Base_task loss_L1L2_wth_mask:  [[87.56, 112.524, 129.237, 106.275], [88.56, 113.524, 126.237, 108.275]]


New_task loss_paper_L1L2:  [[92.014, 95.097, 69.011, 85.444],
                             [93.014, 102.754, 76.514, 102.109]]
New_task loss_L2_with_mask:  [[93.088, 96.365, 69.432, 77.84],[92.018, 96.365, 69.432, 80.84]]
New_task loss_L1_with_mask:  [[87.455, 86.33, 59.374, 73.911], [88.758, 91.227, 69.206, 89.673]]
New_task loss_L1+L2(A)_with_mask:  [[86.236, 90.616, 65.286, 72.759],[89.936, 92.243, 70.39, 90.13]]
New_task loss_L1+L2(B)_with_mask:  [[87.475, 87.206, 64.471, 77.585], [88.975, 91.889, 69.039, 88.866]]
New_task loss_L1L2_wth_mask:  [[87.56, 86.277, 63.671, 75.312], [88.56, 91.841, 69.96, 94.192]]

loss_paper_L1L2:  [[92.014, 104.55689434171978, 110.51408179406951, 101.75078500001169], [93.018, 110.55689434171978, 112.51408179406951, 106.75078500001169] ]
Average_task loss_L2_with_mask:  [[93.088, 105.91387363634611, 112.73769196306195, 95.93520623093016], [92.018, 106.91387363634611, 114.73769196306195, 99.93520623093016]]
Average_task loss_L1_with_mask:  [[87.455, 97.82393112985712, 99.8637478118361, 90.21706431473727], [88.758, 101.32393112985712, 100.8637478118361, 92.21706431473727]]
Average_task loss_L1+L2(A)_with_mask:  [[86.236, 104.28549489232114, 103.44061994693153, 88.98557533996072],[89.936, 106.28549489232114, 105.44061994693153, 90.98557533996072]]
Average_task loss_L1+L2(B)_with_mask:  [[87.475, 97.10866221538343, 104.81776245224268, 96.109102564725], [88.975, 100.90866221538343, 107.81776245224268, 98.109102564725] ]
Average_task loss_L1L2_wth_mask:  [[87.56, 99.40074477667557, 105.74143185237415, 94.53750696753545], [88.56, 100.80074477667557, 106.74143185237415, 96.53750696753545] ]

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(font_scale=1.0)
import pandas as pd


paper_loss= [[92.014, 95.097, 69.011, 85.444],
                             [93.014, 102.754, 76.514, 102.109]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}
num_rounds= 15
num_task = 4
for j in range(len(paper_loss)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(paper_loss[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('L_baseline')
         
dataset = pd.DataFrame(dic)

l1_m=  [[87.455, 86.33, 59.374, 73.911], [88.758, 91.227, 69.206, 89.673]]


dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 4
for j in range(len(l1_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1_m')
          
dataset1 = pd.DataFrame(dic)


l2_m =  [[93.088, 96.365, 69.432, 77.84],[92.018, 96.365, 69.432, 80.84]]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 4
for j in range(len(l2_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l2_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l2_m')
          
dataset2 = pd.DataFrame(dic)


l1l2_A_m=[[86.236, 90.616, 65.286, 72.759],[89.936, 92.243, 70.39, 90.13]]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(l1l2_A_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1l2_A_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1l2_A_m')
          
dataset3 = pd.DataFrame(dic)



l1l2_B_m= [[87.475, 87.206, 64.471, 77.585], [88.975, 91.889, 69.039, 88.866]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(l1l2_B_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1l2_B_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1l2_B_m')
dataset4 = pd.DataFrame(dic)

l1l2_m=  [[87.56, 86.277, 63.671, 75.312], [88.56, 91.841, 69.96, 94.192]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(l1l2_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1l2_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1l2_m')
dataset5 = pd.DataFrame(dic)
#dataset1= dataset1.set_index('Num')
frame= [dataset, dataset1, dataset2, dataset3, dataset4, dataset5]
data= pd.concat(frame)
#sns.lineplot(data= dataset1,x="SHUFFLE", y="NLL", hue='Type', style="Type", markers=True, dashes=[(1, 1)], palette='magma')
#sns.lineplot(data= dataset,x="SHUFFLE", y="NLL",hue='Type', style="Type", markers=True, dashes=[ (5, 10)])

# %%
l= []
for i in range(48):
    l.append(i)
data['Num']= l
plt.figure(figsize=(6,5))
data.set_index('Num',inplace = True)
sns.set_context("paper", font_scale= 1.3, rc={ "axes.titlesize":18,"axes.labelsize":18}) 
sns.lineplot(data= data,x="# Number of tasks", y="Negative log-likelihood", hue="Type", style="Type", markers= True,linewidth=3, dashes=True).set(title='Loss New Task Loss', ylabel= None)
plt.xticks([0,1,2,3])
plt.legend(fontsize= 14.5)
plt.savefig('results/loss_new.pdf')

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(font_scale=1.0)
import pandas as pd


paper_loss= [[92.014, 95.097, 69.011, 85.444],

                             [97.62, 98.754, 76.514, 92.109]
                             ]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}
num_rounds= 15
num_task = 4
for j in range(len(paper_loss)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(paper_loss[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('paper_loss')
         
dataset = pd.DataFrame(dic)

l1_m=  [[87.455, 86.33, 59.374, 73.911], [92.758, 90.227, 63.206, 79.673]]


dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 4
for j in range(len(l1_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1_m')
          
dataset1 = pd.DataFrame(dic)


l2_m = [[93.088, 96.365, 69.432, 77.84],[93.088, 96.365, 69.432, 77.84]]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 4
for j in range(len(l2_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l2_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l2_m')
          
dataset2 = pd.DataFrame(dic)


l1l2_A_m= [[87.236, 90.616, 65.286, 72.759],[92.506, 92.243, 68.39, 80.13]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(l1l2_A_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1l2_A_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1l2_A_m')
          
dataset3 = pd.DataFrame(dic)



l1l2_B_m= [[87.475, 87.206, 64.471, 77.585], [93.533, 91.889, 67.039, 83.866]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(l1l2_B_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1l2_B_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1l2_B_m')
dataset4 = pd.DataFrame(dic)

l1l2_m=  [[84.56, 86.277, 63.671, 75.312], [90.66, 91.841, 69.96, 84.192]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(l1l2_m)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(l1l2_m[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('l1l2_m')
dataset5 = pd.DataFrame(dic)
#dataset1= dataset1.set_index('Num')
frame= [dataset, dataset1, dataset2, dataset3, dataset4, dataset5]
data= pd.concat(frame)
#sns.lineplot(data= dataset1,x="SHUFFLE", y="NLL", hue='Type', style="Type", markers=True, dashes=[(1, 1)], palette='magma')
#sns.lineplot(data= dataset,x="SHUFFLE", y="NLL",hue='Type', style="Type", markers=True, dashes=[ (5, 10)])

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(font_scale=1.0)
import pandas as pd


fcl_lowerbound=    [[57.69, 49.77, 67.11,60.5],
   [57.69, 49.77, 67.11,59.5],
   [57.99, 50.11, 68.11,59.5]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 4
for j in range(len(fcl_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_lowerbound[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('CONFED')
         
dataset = pd.DataFrame(dic)

Fcl_FedWeiT= [[57.69, 50.80, 76.32,68.79],
	[57.69, 50.80, 76.32,69.79],
	[57.69, 50.80, 76.32,68.99]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 4
for j in range(len(Fcl_FedWeiT)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(Fcl_FedWeiT[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('FEDWeIT-MADE')
dataset4 = pd.DataFrame(dic)


fcl_naiveloss_lowerbound=  [[57.69, 49.80, 72.32,63.79],
	[57.69, 49.80, 74.32,64.79],
	[57.69, 50.10, 72.32,64.79]]
	


dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 4
for j in range(len(fcl_naiveloss_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_naiveloss_lowerbound[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDWeIT-MADE*')
          
dataset1 = pd.DataFrame(dic)


femade_lb= [[58.67, 53.39, 88.66, 83.22 ],
   [58.17, 53.39, 88.66, 83.42],
   [58.67, 55.39, 89.66, 84.92 ]]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 4
for j in range(len(femade_lb)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_lb[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-LB')
          
dataset2 = pd.DataFrame(dic)


femade_ub= [[58.67, 55.39, 52.66, 40.42 ],
	[58.67, 56.39, 52.66, 40.92],
	[58.67, 56.99, 52.66, 40.12]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(femade_ub)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_ub[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-UB')
          
dataset3 = pd.DataFrame(dic)
#dataset1= dataset1.set_index('Num')
frame= [dataset, dataset4,dataset1, dataset2, dataset3]
data= pd.concat(frame)

# %%
l= []
for i in range(60):
    l.append(i)
data['Num']= l
plt.figure(figsize=(6, 5))
data.set_index('Num',inplace = True)
sns.set_context("paper", font_scale= 1.3, rc={ "axes.titlesize":18,"axes.labelsize":18}) 
sns.lineplot(data= data,x="# Number of tasks", y="Negative log-likelihood", hue="Type", style="Type", markers= ['o','X','o','*','P'],linewidth= 3, legend=False, dashes=True).set(title='Binary Averaged Task Loss')
plt.xticks([0,1,2,3])
plt.savefig('results/binary_al.pdf')

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(font_scale=1.0)
import pandas as pd


fcl_lowerbound=    [[57.69, 49.81, 52.11, 35.37],
   [57.69, 49.81, 52.11, 35.97],
   [57.69, 48.81, 52.91, 36.37]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 4
for j in range(len(fcl_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_lowerbound[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('CONFEDMADE')
         
dataset = pd.DataFrame(dic)

Fcl_FedWeiT= [[57.69, 51.91, 53.91, 38.57],
	[57.69, 50.91, 54.91, 37.57],
	[57.69, 51.81, 55.21, 37.57]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 4
for j in range(len(Fcl_FedWeiT)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(Fcl_FedWeiT[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('FEDWeIT-MADE')
dataset4 = pd.DataFrame(dic)


fcl_naiveloss_lowerbound=  [[57.69, 49.91, 51.91, 36.57],
	[57.69, 49.51, 50.91, 36.57],
	[57.69, 49.81, 50.91, 36.97]]
	


dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 4
for j in range(len(fcl_naiveloss_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_naiveloss_lowerbound[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDWeIT-MADE*')
          
dataset1 = pd.DataFrame(dic)


femade_lb= [[58.67, 50.39, 52.66, 41.42 ],
   [58.67, 50.39, 52.66, 41.42],
   [58.67, 51.39, 53.66, 40.42 ]]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 4
for j in range(len(femade_lb)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_lb[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-LB')
          
dataset2 = pd.DataFrame(dic)


femade_ub= [[58.67, 51.39, 59.66, 61.42 ],
	[58.67, 51.39, 59.66, 61.42],
	[58.67, 51.19, 58.66, 62.42]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(femade_ub)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_ub[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-UB')
          
dataset3 = pd.DataFrame(dic)
#dataset1= dataset1.set_index('Num')
frame= [dataset, dataset4,dataset1, dataset2, dataset3]
data= pd.concat(frame)

# %%
l= []
for i in range(60):
    l.append(i)
data['Num']= l
plt.figure(figsize=(6, 5))
data.set_index('Num',inplace = True)
sns.set_context("paper", font_scale= 1.3, rc={ "axes.titlesize":18,"axes.labelsize":18}) 
sns.lineplot(data= data,x="# Number of tasks", y="Negative log-likelihood", hue="Type", style="Type", markers= ['o','X','o','*','P'],linewidth= 3, legend=True, dashes=True).set(title='Binary New Task Loss',ylabel=None)
plt.xticks([0,1,2,3])
plt.savefig('results/binary_nl.pdf')

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(font_scale=1.0)
import pandas as pd


fcl_lowerbound=    [[57.69, 49.76, 55.52, 60.56],
   [57.69, 49.76, 55.52, 60.56],
   [57.69, 49.16, 55.52, 59.16]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 4
for j in range(len(fcl_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_lowerbound[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('CONFED')
         
dataset = pd.DataFrame(dic)

Fcl_FedWeiT= [[57.69, 49.79, 58.52, 64.56],
	[57.69, 49.79, 58.52, 64.56],
	[57.89, 49.19, 58.92, 63.56]]
sns.set(font_scale=1.0)
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 4
for j in range(len(Fcl_FedWeiT)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(Fcl_FedWeiT[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('FEDWeIT-MADE')
dataset4 = pd.DataFrame(dic)


fcl_naiveloss_lowerbound=  [[57.99, 49.99, 64.52, 70.56],
	[57.99, 49.99, 64.82, 69.56],
	[57.99, 50.19, 63.92, 68.56]]
	


dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 4
for j in range(len(fcl_naiveloss_lowerbound)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(fcl_naiveloss_lowerbound[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDWeIT-MADE*')
          
dataset1 = pd.DataFrame(dic)


femade_lb= [[58.67, 55.89, 68.66, 91.42 ],
   [58.67, 55.39, 68.66, 91.42 ],
   [58.67, 54.39, 69.66, 88.12  ]]
dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],

            'Type':[]}

num_task = 4
for j in range(len(femade_lb)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_lb[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-LB')
          
dataset2 = pd.DataFrame(dic)


femade_ub= [[58.67, 59.39, 41.66, 32.42 ],
	[58.67, 60.39, 41.66, 32.42],
	[58.67, 58.39, 40.16, 33.42]]

dic = {'Negative log-likelihood':[],
            '# Number of tasks':[],
            'Type':[]}

num_task = 4
for j in range(len(femade_ub)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Negative log-likelihood'].append(femade_ub[j][i])
        dic['# Number of tasks'].append(i)

        dic['Type'].append('FEDCL-UB')
          
dataset3 = pd.DataFrame(dic)
#dataset1= dataset1.set_index('Num')
frame= [dataset, dataset4,dataset1, dataset2, dataset3]
data= pd.concat(frame)

# %%
l= []
for i in range(60):
    l.append(i)
data['Num']= l
plt.figure(figsize=(6, 5))
data.set_index('Num',inplace = True)
sns.set_context("paper", font_scale= 1.3, rc={ "axes.titlesize":18,"axes.labelsize":18}) 
sns.lineplot(data= data,x="# Number of tasks", y="Negative log-likelihood", hue="Type", style="Type", markers= ['o','X','o','*','P'],linewidth= 3, legend=False, dashes=True).set(title='Binary Base Task Loss',ylabel=None)
plt.xticks([0,1,2,3])
plt.savefig('results/binary_bl.pdf')

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set(font_scale=1.0)
import pandas as pd


WMB=    [[60.23, 24.32, 14.32, 11.17],
   [60.23, 24.32, 14.32, 11.17],
   [60.23, 24.32, 14.32, 11.17]]
sns.set(font_scale=1.0)
dic = {'Accuracy':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 4
for j in range(len(WMB)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Accuracy'].append(WMB[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('Without Mem Buffer')
         
dataset = pd.DataFrame(dic)

MB=    [[60.23, 27.32, 28.32, 29.17],
   [60.23, 27.32, 28.32, 29.17],
   [60.23, 27.32, 28.32, 29.17]]
sns.set(font_scale=1.0)
dic = {'Accuracy':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 4
for j in range(len(MB)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Accuracy'].append(MB[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('With Mem Buffer')
         
dataset1 = pd.DataFrame(dic)

RMB=    [[60.23, 17.32, 13.32, 10.17],
   [60.23, 17.32, 13.32, 10.17],
   [60.23, 17.32, 13.32, 10.17]]
sns.set(font_scale=1.0)
dic = {'Accuracy':[],
            '# Number of tasks':[],
           
            'Type':[]}

num_task = 4
for j in range(len(RMB)):
    for i in range(num_task):
    #for j in range(num_rounds):
        dic['Accuracy'].append(RMB[j][i])
        dic['# Number of tasks'].append(i)
        dic['Type'].append('Relevance With Mem Buffer')
         
dataset2 = pd.DataFrame(dic)




#dataset1= dataset1.set_index('Num')
frame= [dataset, dataset1, dataset2]
data= pd.concat(frame)

# %%
l= []
for i in range(36):
    l.append(i)
data['Num']= l
plt.figure(figsize=(6, 5))
data.set_index('Num',inplace = True)
sns.set_context("paper", font_scale= 1.3, rc={ "axes.titlesize":18,"axes.labelsize":18}) 
sns.lineplot(data= data,x="# Number of tasks", y="Accuracy", hue="Type", style="Type", markers= ['o','X','o'],linewidth= 3, dashes=True).set(title='ViT')
plt.xticks([0,1,2,3])
plt.savefig('results/binary_bl.pdf')
